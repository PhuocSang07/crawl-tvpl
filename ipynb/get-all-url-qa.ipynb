# %%
import json
import requests
from bs4 import BeautifulSoup
import os
import time
from random import choice
from typing import List, Optional
import pandas as pd 
from concurrent.futures import ThreadPoolExecutor

# %%
def clean_text(text):
    return text.strip() if text else ""

def remove_link_tag(links):
    return [link for link in links if link]

# %%
def get_type_of_law(url):
    text = url.split("/")[4]
    return text.split("?")[0]

# %%
PROJECT_ROOT = "/kaggle/working/"
PROXY_LIST_PATH = os.path.join(PROJECT_ROOT, 'config', 'proxy_list.txt')

def create_proxy_list():
    PROXY_URL = 'https://api.proxyscrape.com/v2/?request=displayproxies&protocol=http&timeout=10000&country=all&ssl=all&anonymity=all'
    proxy_list = requests.get(PROXY_URL)
    os.makedirs(os.path.dirname(PROXY_LIST_PATH), exist_ok=True)
    with open(PROXY_LIST_PATH, 'w') as f:
        f.write(proxy_list.text.replace('\r\n', '\n'))

def choice_proxy() -> Optional[str]:
    if not os.path.exists(PROXY_LIST_PATH):
        create_proxy_list()
    
    with open(PROXY_LIST_PATH, 'r') as f:
        proxies = f.read().split('\n')
        return choice(proxies)

# %%
def load_url(url: str, return_content: bool = False) -> Optional[str]:
    """Load URL content with error handling."""
    proxy = choice_proxy()
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    try:
        response = requests.get(url, headers=headers, proxies={'http': proxy}, timeout=10)
        response.raise_for_status()
        if not return_content:
            return response
        else:
            soup = BeautifulSoup(response.content, 'html.parser')
            return soup
    except Exception as e:
        # Ghi log lỗi ra file hoặc danh sách
        with open("failed_links.txt", "a") as log_file:
            log_file.write(f"{url}\t{str(e)}\n")
        print(f"Failed to load {url}: {e}")
        return None

# %%
def get_all_sub_qa_url(url: str) -> List[str]:
    """Get all sub-URLs from the main QA URL."""
    soup = load_url(url, return_content=True)
    # Extract article links
    articles = soup.select('article')
    keywords = []
    time = []
    date = []
    links = []
    type_qa = []

    type_url = get_type_of_law(url)
    for article in articles:
        tag_a = article.find('a', class_='title-link')
        links.append("https://thuvienphapluat.vn" + tag_a.get("href") if tag_a else None)
        type_qa.append(type_url)
        # Keyword
        keyword_find = article.select('.d-block.sub-item-head-keyword')
        if keyword_find:
            keywords.append([kw.get_text(strip=True) for kw in keyword_find])
        else:
            keywords.append([None])
            
         # Get sub-time
        sub_time_tag = article.find('span', class_='sub-time')
        if sub_time_tag:
            time.append(sub_time_tag.get_text(strip=True).replace(" ","").split("|")[0])
            date.append(sub_time_tag.get_text(strip=True).replace(" ","").split("|")[1])
        else:
            time.append(None)
            date.append(None)
        
    df = pd.DataFrame(list(zip(links, keywords, date, time, type_qa)), columns =['link', 'keyword', "date", "time", "type"])
    return df

# %%
base_url = [ 
    "https://thuvienphapluat.vn/phap-luat/cong-nghe-thong-tin?page={}",
    "https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page={}",
    "https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page={}",
    "https://thuvienphapluat.vn/phap-luat/bat-dong-san?page={}",
    "https://thuvienphapluat.vn/phap-luat/vi-pham-hanh-chinh?page={}",
    "https://thuvienphapluat.vn/phap-luat/bao-hiem?page={}",
    "https://thuvienphapluat.vn/phap-luat/quyen-dan-su?page={}",
    "https://thuvienphapluat.vn/phap-luat/van-hoa-xa-hoi?page={}",
    "https://thuvienphapluat.vn/phap-luat/thuong-mai?page={}",
    "https://thuvienphapluat.vn/phap-luat/trach-nhiem-hinh-su?page={}",
    "https://thuvienphapluat.vn/phap-luat/xay-dung-do-thi?page={}",
    "https://thuvienphapluat.vn/phap-luat/chung-khoan?page={}",
    "https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page={}",
    "https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page={}",
    "https://thuvienphapluat.vn/phap-luat/xuat-nhap-khau?page={}",
    "https://thuvienphapluat.vn/phap-luat/tien-te-ngan-hang?page={}",
    "https://thuvienphapluat.vn/phap-luat/dau-tu?page={}",
    "https://thuvienphapluat.vn/phap-luat/so-huu-tri-tue?page={}",
    "https://thuvienphapluat.vn/phap-luat/thu-tuc-to-tung?page={}",
    "https://thuvienphapluat.vn/phap-luat/tai-chinh-nha-nuoc?page={}",
    "https://thuvienphapluat.vn/phap-luat/the-thao-y-te?page={}",
    "https://thuvienphapluat.vn/phap-luat/dich-vu-phap-ly?page={}",
    "https://thuvienphapluat.vn/phap-luat/tai-nguyen-moi-truong?page={}",
    "https://thuvienphapluat.vn/phap-luat/cong-nghe-thong-tin?page={}",
    "https://thuvienphapluat.vn/phap-luat/giao-duc?page={}",
    "https://thuvienphapluat.vn/phap-luat/giao-thong-van-tai?page={}",
    "https://thuvienphapluat.vn/phap-luat/hanh-chinh?page={}",
    "https://thuvienphapluat.vn/phap-luat/linh-vuc-khac?page={}"
    ]

num_page = 500
num_page_urls = [url.format(i) for url in base_url for i in range(1, num_page)]

# %%
def process_url(url: str):
    try:
        df = get_all_sub_qa_url(url)
        return df
    except Exception as e:
        with open("failed_links.txt", "a") as log_file:
            log_file.write(f"{url}\t{str(e)}\n")
        print(f"Error processing {url}: {e}")
        return None

# %%
# %%time 
def process_urls_multithreaded(urls, max_workers=10):
    dfs = []
    failed_urls = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        results = executor.map(process_url, urls)
        for url, result in zip(urls, results):
            if result is not None:
                dfs.append(result)
            else:
                failed_urls.append(url)
    
    if failed_urls:
        with open("failed_links_summary.txt", "w") as f:
            for url in failed_urls:
                f.write(url + "\n")
    
    if dfs:
        final_df = pd.concat(dfs, ignore_index=True)
        return final_df
    else:
        return pd.DataFrame()  

df = process_urls_multithreaded(num_page_urls, max_workers=1024)
# Out:
# Failed to load https://thuvienphapluat.vn/phap-luat/cong-nghe-thong-tin?page=304: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/cong-nghe-thong-tin?page=304: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/cong-nghe-thong-tin?page=332: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/cong-nghe-thong-tin?page=341: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/cong-nghe-thong-tin?page=330: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/cong-nghe-thong-tin?page=332: 'NoneType' object has no attribute 'select'Error processing https://thuvienphapluat.vn/phap-luat/cong-nghe-thong-tin?page=330: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/cong-nghe-thong-tin?page=341: 'NoneType' object has no attribute 'select'
#
# Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=137: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=137: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=182: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=159: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=162: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=159: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=182: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=162: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=275: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=275: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=452: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=492: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=475: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=462: HTTPSConnectionPool(host='thuvienphapluat.vn', port=443): Max retries exceeded with url: /phap-luat/doanh-nghiep?page=462 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:2426)')))
#
# Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=462: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=452: 'NoneType' object has no attribute 'select'Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=485: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=4: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=497: HTTPSConnectionPool(host='thuvienphapluat.vn', port=443): Max retries exceeded with url: /phap-luat/doanh-nghiep?page=497 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:2426)')))
#
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=4: 'NoneType' object has no attribute 'select'Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=475: 'NoneType' object has no attribute 'select'
#
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=15: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=497: 'NoneType' object has no attribute 'select'Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=492: 'NoneType' object has no attribute 'select'
#
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=49: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=1: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/doanh-nghiep?page=485: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=1: 'NoneType' object has no attribute 'select'Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=50: HTTPSConnectionPool(host='thuvienphapluat.vn', port=443): Max retries exceeded with url: /phap-luat/lao-dong-tien-luong?page=50 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:2426)')))
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=68: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=45: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=55: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=69: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=91: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=49: 'NoneType' object has no attribute 'select'Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=56: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=68: 'NoneType' object has no attribute 'select'
#
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=50: 'NoneType' object has no attribute 'select'Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=45: 'NoneType' object has no attribute 'select'Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=15: 'NoneType' object has no attribute 'select'
#
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=91: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=56: 'NoneType' object has no attribute 'select'
#
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=81: HTTPSConnectionPool(host='thuvienphapluat.vn', port=443): Max retries exceeded with url: /phap-luat/lao-dong-tien-luong?page=81 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:2426)')))
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=55: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=69: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=81: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=125: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=141: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=125: 'NoneType' object has no attribute 'select'Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=177: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=141: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=207: HTTPSConnectionPool(host='thuvienphapluat.vn', port=443): Max retries exceeded with url: /phap-luat/lao-dong-tien-luong?page=207 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:2426)')))
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=187: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=130: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=176: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=177: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=202: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=207: 'NoneType' object has no attribute 'select'
#
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=151: HTTPSConnectionPool(host='thuvienphapluat.vn', port=443): Max retries exceeded with url: /phap-luat/lao-dong-tien-luong?page=151 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:2426)')))
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=176: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=298: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=187: 'NoneType' object has no attribute 'select'Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=273: HTTPSConnectionPool(host='thuvienphapluat.vn', port=443): Max retries exceeded with url: /phap-luat/lao-dong-tien-luong?page=273 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:2426)')))
#
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=186: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=298: 'NoneType' object has no attribute 'select'Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=130: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=202: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=273: 'NoneType' object has no attribute 'select'Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=349: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
#
#
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=293: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=186: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=151: 'NoneType' object has no attribute 'select'Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=349: 'NoneType' object has no attribute 'select'
#
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=293: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=387: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=387: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=390: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=402: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=456: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page=389: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/lao-dong-tien-luong?page
failed to load https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=364: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=271: 'NoneType' object has no attribute 'select'
#
# Failed to load https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=386: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=427: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=427: 'NoneType' object has no attribute 'select'Error processing https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=364: 'NoneType' object has no attribute 'select'
#
# Error processing https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=386: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=344: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))Failed to load https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=416: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Error processing https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=416: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=344: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=492: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=18: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to load https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=60: HTTPSConnectionPool(host='thuvienphapluat.vn', port=443): Max retries exceeded with url: /phap-luat/thue-phi-le-phi?page=60 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:2426)')))Failed to load https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=89: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Error processing https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=18: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=89: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/ke-toan-kiem-toan?page=492: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=111: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))Failed to load https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=169: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Error processing https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=111: 'NoneType' object has no attribute 'select'Error processing https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=60: 'NoneType' object has no attribute 'select'
# Error processing https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=169: 'NoneType' object has no attribute 'select'
#
# Failed to load https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=253: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=253: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=238: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=238: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=268: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=268: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=277: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing https://thuvienphapluat.vn/phap-luat/thue-phi-le-phi?page=277: 'NoneType' object has no attribute 'select'
# Failed to load https://thuvienphapluat.vn/phap-luat/giao-thong-van-tai?page=54: 500 Server Error: Internal Server Error for url: https://thuvienphapluat.vn/phap-luat/giao-thong-van-tai?page=54
# Error processing https://thuvienphapluat.vn/phap-luat/giao-thong-van-tai?page=54: 'NoneType' object has no attribute 'select'
# CPU times: user 43min 2s, sys: 13min 34s, total: 56min 37s
# Wall time: 35min 39s

# %%
df
# Out:
#                                                      link  \
# 0       https://thuvienphapluat.vn/phap-luat/khong-gia...
# 1       https://thuvienphapluat.vn/phap-luat/mua-bao-h...
# 2                                                    None
# 3       https://thuvienphapluat.vn/phap-luat/ho-tro-ph...
# 4       https://thuvienphapluat.vn/phap-luat/ho-tro-ph...
# ...                                                   ...
# 191222  https://thuvienphapluat.vn/phap-luat/co-so-san...
# 191223                                               None
# 191224  https://thuvienphapluat.vn/phap-luat/giong-cay...
# 191225  https://thuvienphapluat.vn/phap-luat/trang-thi...
# 191226  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...
#
#                                                  keyword        date   time  \
# 0                                        [Bảo vệ trẻ em]  11/01/2025  02:40
# 1                                      [Bảo hiểm xe máy]  10/01/2025  14:04
# 2                                                 [None]        None   None
# 3                                   [Dịch vụ viễn thông]  10/01/2025  12:25
# 4       [Giấy phép cung cấp dịch vụ trò chơi điện tử G1]  10/01/2025  11:32
# ...                                                  ...         ...    ...
# 191222                            [Trồng trọt, Phân bón]  06/03/2022  17:42
# 191223                                            [None]        None   None
# 191224                     [Trồng trọt, Giống cây trồng]  06/03/2022  17:39
# 191225                            [Trồng trọt, Canh tác]  06/03/2022  17:26
# 191226                 [Chăn nuôi, Chăn nuôi trang trại]  03/03/2022  18:45
#
#                        type
# 0       cong-nghe-thong-tin
# 1       cong-nghe-thong-tin
# 2       cong-nghe-thong-tin
# 3       cong-nghe-thong-tin
# 4       cong-nghe-thong-tin
# ...                     ...
# 191222        linh-vuc-khac
# 191223        linh-vuc-khac
# 191224        linh-vuc-khac
# 191225        linh-vuc-khac
# 191226        linh-vuc-khac
#
# [191227 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191227 entries, 0 to 191226
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   link     173011 non-null  object
#  1   keyword  191227 non-null  object
#  2   date     173011 non-null  object
#  3   time     173011 non-null  object
#  4   type     191227 non-null  object
# dtypes: object(5)
# memory usage: 7.3+ MB

# %%
data = df.dropna().reset_index()

# %%
data.to_csv("data.csv")
